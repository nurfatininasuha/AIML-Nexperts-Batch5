# %%
text = """
Forests are nature’s living cathedrals, where towering trees weave a green canopy that hums with life.
Beneath their shade, the air feels cooler, richer, and alive with the scent of earth and leaves.
Sunlight filters through in golden shards, dancing on mossy ground and whispering streams.
Every rustle in the undergrowth hints at hidden creatures—birds calling from above,
insects buzzing in the air, and animals moving quietly in the shadows. Forests are not just collections
of trees; they are breathing, evolving worlds that shelter countless species,
store ancient secrets, and remind us of the delicate balance that sustains life on Earth.
"""

# %%
sentences = text.split(".")
len(sentences)

words = text.split(" ")
len(words)

char_tokens = list(text.lower().replace(" ",""))
len(char_tokens)
# Out:
# 554

# %%
newtext = text
newtext = newtext.replace("\n", " ")
newtext = newtext.replace(".", "")
newtext = newtext.replace(",", "")
newtext = newtext.replace("—", " ")
newtext = newtext.replace("'", "")
newtext = newtext.lower()
newtext
# Out:
# ' forests are nature’s living cathedrals where towering trees weave a green canopy that hums with life beneath their shade the air feels cooler richer and alive with the scent of earth and leaves sunlight filters through in golden shards dancing on mossy ground and whispering streams every rustle in the undergrowth hints at hidden creatures birds calling from above insects buzzing in the air and animals moving quietly in the shadows forests are not just collections of trees; they are breathing evolving worlds that shelter countless species store ancient secrets and remind us of the delicate balance that sustains life on earth '

# %%
stopwords = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
tokens = text.replace("\n", "")
tokens = tokens.replace(".", "")
tokens = tokens.replace(",", "")
tokens = tokens.replace("—", " ")
tokens = tokens.replace("’", "")
tokens = tokens.lower()
tokens

tokens = tokens.split(" ")
len(tokens)
# Out:
# 96

# %%
len(text.split())

clean_text = [word for word in tokens if word not in stopwords]
len(clean_text)
# Out:
# 60

# %%
#EXERCISE

print("Please insert your prompt")
user_input = input("Ask me a question: ")
 
def prompt(user_input):
 
    # Original Prompt
    print("Initial prompt by user:")
    print("-"*30)
    print(f"{user_input}")
    print("="*30)   
 
    # Lowercase
    newtext = user_input.lower()
 
    # Tokenize
    newtext_token = user_input.split()
 
    # Number of token
    newtext_number_of_token = len(newtext_token)
    
    print(f"Number of token {newtext_number_of_token}")
    print("="*30)
 
    # Stop word removal
    stopwords = ['the', 'a', 'an', 'in', 'on', 'at', 'and', 'or', 'but',
                 'i', 'you', 'he', 'she', 'is', 'am', 'are']
   
    clean_newtext = [word for word in newtext_token if word not in stopwords]
 
    # Calculate new tokens
    newtext_token_after_removal = len(clean_newtext)
    
    print(f"Number of token after removal of stop words: {newtext_token_after_removal}")
    print("="*30)
 
    # Set limit = 50
    set_limit = 50
 
    # warning
    if newtext_token_after_removal < set_limit:
        print("="*30)
        print("Looking for answers, wait for the response...")
        print("="*30)
        print(f"Here are the answer: ")
        print("="*30)
        print(f"{clean_newtext}")
        print("="*30)
 
    else:
        print("="*30)
        print("\nToken has reached limit. Suscribe our plan for further usage")
 
prompt(user_input)

# %%
#pip install nltk

# %%
import nltk

from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

sentence = "Forests are breathing and evolving worlds that shelter countless species."

stemmed_words = [stemmer.stem(word) for word in sentence.split()]


print(" ".join(stemmed_words))
# Out:
# forest are breath and evolv world that shelter countless species.

# %%
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

sentence = "Forests are breathing and evolving worlds that shelter countless species."
words = sentence.lower().split()

lemmatized_words = [lemmatizer.lemmatize(word, pos= 'v') for word in words]

" ".join(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Nurfatini
# [nltk_data]     Nasuha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 'forest be breathe and evolve worlds that shelter countless species.'

# %%
lemmatizer.lemmatize('happiness', pos= 'n')
# Out:
# 'happiness'

# %%
ord('d')

letters = ['A','B','C', 'a', 'b', 'c','!','@','#']
for letter in letters:
    ASCII_code = ord(letter)
    print(f"ASCII of {letter} ---> {ASCII_code}")
# Out:
# ASCII of A ---> 65
# ASCII of B ---> 66
# ASCII of C ---> 67
# ASCII of a ---> 97
# ASCII of b ---> 98
# ASCII of c ---> 99
# ASCII of ! ---> 33
# ASCII of @ ---> 64
# ASCII of # ---> 35

# %%
letter = '😊'
encoded_letter = letter.encode('utf-8')
encoded_letter
# type(encoded_letter)

encoded_letter.decode()
# Out:
# '😊'
